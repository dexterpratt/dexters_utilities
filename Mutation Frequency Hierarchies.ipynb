# %% [markdown]
# ## Applying genetic alteration data to hierarchies

# %%
import ndex2
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from cyjupyter import Cytoscape
# %matplotlib inline

# %%
NETWORK_UUID = "9a8f5326-aa6e-11ea-aaef-0ac135e8bacf"
SERVER = "https://ndexbio.org"
test_network = ndex2.create_nice_cx_from_server(SERVER, uuid=NETWORK_UUID)
test_network.print_summary()
# Out:
# Name: NeST Map - Main Model
# Nodes: 395
# Edges: 466
# Node Attributes: 9799
# Edge Attributes: 881

# %%
#os.getcwd()
mutation_file=os.path.join(os.path.abspath(''), "bc_all_mutations.txt")

# %%
## the mutation data
bc_mutations = pd.read_csv(mutation_file, sep="\t")
bc_mutations
# Out:
#           Gene  MutSig(Q-value)  # Mut   #  Profiled Samples  Freq  \
# 0      FAM200B              NaN     16  16              3102  0.5%
# 1        STPG2              NaN      3   3              1282  0.2%
# 2        KRT6C              NaN      7   7              2606  0.3%
# 3        INSL3              NaN      3   3              1573  0.2%
# 4         ASPM              NaN    114  94              4474  2.1%
# ...        ...              ...    ...  ..               ...   ...
# 18378     OCRL              NaN     40  38              4249  0.9%
# 18379    INPP1              NaN      6   6              2501  0.2%
# 18380     ODF1              NaN     11  11              3532  0.3%
# 18381     ODF2              NaN     44  40              4227  0.9%
# 18382   CXCL10              NaN      3   3              2865  0.1%
#
#       Is Cancer Gene (source: OncoKB)
# 0                                  No
# 1                                  No
# 2                                  No
# ...
